# %% [markdown]
# # Setup Google colab

# %%
# install packages
# !pip install ipympl
# !pip install defdap

# get data files
from pathlib import Path
def create_url_file(url_base, dir_name, file_names):
  url_file = Path(f"{dir_name}/url_list")
  url_file.parent.mkdir(exist_ok=True, parents=True)
  with url_file.open("w") as f:
    f.writelines(["/".join([url_base, dir_name, fn])+"\n" for fn in file_names])
url_base = "https://github.com/MechMicroMan/DefDAP_workshop/raw/main/data"
file_names = ["ebsd.cpr", "ebsd.crc", "hrdic.txt", "pattern.jpg"]
# !mkdir data
# %cd data
create_url_file(url_base, "ni", file_names)
# %cd ni
# !wget -i url_list
# %cd /content/data
create_url_file(url_base, "ti", file_names[:-1])
# %cd ti
# !wget -i url_list
# %cd /content/data
create_url_file(url_base, "zr/irr", file_names)
# %cd zr/irr
# !wget -i url_list
# %cd /content/data
create_url_file(url_base, "zr/nirr", file_names)
# %cd zr/nirr
# !wget -i url_list
# %cd /content

# %% [markdown]
# # DefDAP Advanced notebook
#
# This notebook will outline usage of DefDAP, including loading a DIC and EBSD map, linking them with homologous points, producing maps, drawing line profiles and performing slip system analysis using grain inspector.

# %% [markdown]
# This notebook contains the dataset used in the following paper: https://www.sciencedirect.com/science/article/pii/S2589152919300444 which is available at this respository: https://data.mendeley.com/datasets/n4cdwp6pwc/1 or in the workshop download package.

# %% [markdown]
# ### Load packages

# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap

from defdap import ebsd, hrdic
from defdap.plotting import HistPlot
from defdap.quat import Quat

from google.colab import output
output.enable_custom_widget_manager()

# %matplotlib widget

# %% [markdown]
# ### Load DIC data

# %%
file_path = Path("data/zr/")

irrMap = hrdic.Map(file_path / "irr/hrdic.txt")
irrMap.set_pattern("pattern.jpg", 2)

nirrMap = hrdic.Map(file_path / "nirr/hrdic.txt")
nirrMap.set_pattern("pattern.jpg", 2)

for dic_map in [irrMap, nirrMap]:
    dic_map.set_crop(left=0, right=0, top=0, bottom=0)
    dic_map.set_scale((10/2048))

# %% [markdown]
# ### Load EBSD data

# %%
irrEbsd = ebsd.Map(file_path / "irr/ebsd.cpr")
nirrEbsd = ebsd.Map(file_path / "nirr/ebsd.cpr")

for ebsd_map in [nirrEbsd, irrEbsd]:
    ebsd_map.data.generate('grain_boundaries', misori_tol=3.6)
    ebsd_map.data.generate('grains', min_grain_size=20)
    ebsd_map.calc_average_grain_schmid_factors(load_vector=np.array([1, 0, 0]))
    ebsd_map.calc_grain_mis_ori(calc_axis=True)

# %% [markdown]
# You can try to select your own homologous points using these functions, or you can use predefined ones in the following cell

# %%
irrMap.set_homog_point(map_name='pattern')

# %%
irrEbsd.set_homog_point()
plt.show()

# %%
irrMap.frame.homog_points = [
    (939, 170), (132, 220), (226, 860), (942, 864), (530, 430)
]
nirrMap.frame.homog_points = [
    (98, 126), (99, 884), (880, 100), (555, 614), (483, 106), (936, 696)
]
irrEbsd.frame.homog_points = [
    (407, 106), (85, 109), (112, 329), (392, 342), (240, 186)
]
nirrEbsd.frame.homog_points = [
    (62, 60), (46, 339), (373, 69), (229, 250), (217, 59), (378, 295)
]

# %% [markdown]
# ### Link maps

# %%
irrMap.link_ebsd_map(irrEbsd, transform_type='affine')
irrMap.find_grains(algorithm='warp');

nirrMap.link_ebsd_map(nirrEbsd, transform_type='affine')
nirrMap.find_grains(algorithm='warp');

# %% [markdown]
# ### Draw a line profile

# %%
nirrMap.draw_line_profile(vmax=0.2)
plt.show()

# %%
nirrMap.plot_default()
plt.show()

# %%
nirrMap.plot_map('max_shear')

# %%
irrMap.draw_line_profile(vmax=0.2)

# %% [markdown]
# ### Stats

# %%
irrMap.print_stats_table(
    percentiles=[0, 1, 5, 50, 95, 99, 100], 
    components=['e','max_shear']
)
nirrMap.print_stats_table(
    percentiles=[0, 1, 5, 50, 95, 99, 100], 
    components=['e', 'max_shear']
)

# %% [markdown]
# ### Comparison plots

# %%
# New colour map with red when saturated
viridis = cm.get_cmap('viridis', 512)
newcolors = viridis(np.linspace(0, 1, 512))
newcolors[-1:, :] = np.array([1, 0, 0, 1])
newcmp = ListedColormap(newcolors)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5), constrained_layout=True)

plot0 = nirrMap.plot_map(
    'max_shear', ax=ax1, fig=fig, plot_colour_bar=False,
    vmin=0, vmax=0.2, cmap = newcmp, plot_gbs='line'
)
plot1 = irrMap.plot_map(
    'max_shear', ax=ax2, fig=fig, plot_colour_bar=False, plot_scale_bar=True, 
    vmin=0, vmax=0.2, cmap = newcmp, plot_gbs='line'
)

plot1.add_colour_bar(label='Effective Shear Strain', aspect=35, shrink=0.86)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5), constrained_layout=True)

plot0 = nirrEbsd.plot_mis_ori_map(ax=ax1, fig=fig,component=3, 
                              plot_gbs='line', boundary_colour='black',
                              plot_colour_bar = False, cmap='coolwarm',
                              vmin=-4, vmax=4)
plot1 = irrEbsd.plot_mis_ori_map(ax=ax2, fig=fig, component=3, 
                               plot_gbs='line', boundary_colour='black',
                               plot_colour_bar=False, cmap='coolwarm',
                               vmin=-4, vmax=4)

plot1.add_colour_bar(label='Rotation about Z ($^\circ$)', aspect=35, shrink=0.86)

# %% [markdown]
# ### Histogram

# %%
plot = HistPlot.create(
    irrMap.crop(irrMap.data['max_shear']) / np.nanmedian(irrMap.crop(irrMap.data['max_shear'])),
    plot_type='step', axes_type="loglog", bins=200, 
    range=(0.0001,100), label='Irradiated', alpha=0.6
)

plot.add_hist(
    nirrMap.crop(nirrMap.data['max_shear']) / np.nanmedian(nirrMap.crop(nirrMap.data['max_shear'])), 
    bins=200, range=(0.0001,100), label = 'Unirradiated', alpha=0.6
)

plot.add_legend()

plot.ax.set_xlabel("Effective shear strain (multiples of median)")
plot.ax.set_xlim(0.01, 50)
plot.ax.set_ylim(0.0001)

plt.axvline(1, color='black', linestyle='dashed', linewidth=1)

plt.tight_layout()

# %% [markdown]
# ### Grain inspector

# %% [markdown]
# This will load a GUI tool used to inspect the slip in each grain. You can navigate between grains using the 'Previous Grain' and 'Next Grain' buttons in the top right. Click and drag within the grain to define slip lines and click the 'Save Line' button to the right to save and detect the active slip system.

# %%
irrMap.grain_inspector(vmax=0.1)

# %%
nirrMap.grain_inspector(vmax=0.1)

# %% [markdown]
# ### Plot grains

# %% [markdown]
# After drawing lines on some grains above, this code will plot an IPF with the active slip system coloured.

# %%
selMap = irrMap

prorilist = []; pyorilist=[]; baorilist=[]; multorilist = [];
for grain in selMap:
    for system in grain.groups_list:
        # If one slip system
        if len(system[2]) == 1:
            # If prismatic
            if system[2][0] in [1, 2, 3]:
                prorilist.append(grain.ref_ori)
            # If pyramidal
            if system[2][0] in [4, 5, 6, 7, 8, 9]:
                pyorilist.append(grain.ref_ori)
            #If basal
            if system[2][0] in [0]:
                pyorilist.append(grain.ref_ori)
        #If ambiguous
        if len(system[2]) >1:
            multorilist.append(grain.ref_ori)

f, ax = plt.subplots(figsize=(6,4))

markersize=40
    
Quat.plot_ipf(
    [grain.ref_ori for grain in selMap], [1,0,0], 'hexagonal',
    c='0.9', marker='o', s=markersize, ax=ax, label='no slip'
)
if multorilist != []: 
    Quat.plot_ipf(
        multorilist, [1,0,0], 'hexagonal', 
        c='0.6', marker='o', s=markersize, ax=ax, label='ambiguous'
    )
if prorilist != []: 
    Quat.plot_ipf(
        prorilist, [1,0,0], 'hexagonal', 
        c='r', marker='o', s=markersize, ax=ax, label='prismatic'
    )
if pyorilist != []:
    Quat.plot_ipf(
        pyorilist, [1,0,0], 'hexagonal', 
        c='g', marker='o', s=markersize, ax=ax, label='pyramidal'
    )
if baorilist != []:
    Quat.plot_ipf(
        baorilist, [1,0,0], 'hexagonal', 
        c='b', marker='o', s=markersize, ax=ax, label='basal'
    )

plt.legend(loc='upper left')
